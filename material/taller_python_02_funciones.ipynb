# %% [markdown]
# # Funciones
#
# Las funciones en Python deben ser declaradas mediante la sentencia bajo el siguiente patrón:
#
# ```python
# def nombre_funcion(argumento_1, argumento_2, ..., argumento_n):
#
#     bloque_de_instrucciones
#
#     return salida
# ```

# %%
def valor_absoluto(x):
    """
    Siempre es bueno comentar lo que hace la función a través de docstrings.
    
    Input:
    x: que es x
    
    Output:
    el valor absoluto de x.
    """
    if x < 0:
        a = -x
    else:
        a = x
        
    return a

# %%
valor_absoluto(-5)

# %% [markdown]
# Las funciones pueden tener valores por defecto. Si uno de los variables por defecto no tendrá un valor definido, puede declararse como `None`.

# %%
def suma(x, y=0):
    print(x + y, y)

# %%
suma(4)

# %%
def division(x: float, y: float = 1.0) -> float:
    if y == 0:
        print('No se puede dividir por cero')
        return None
    else:
        return x / y

# %%
division(10)

# %% [markdown]
# Las funciones pueden retornar más de un valor.

# %%
def to_meters(centimeters):
    m = centimeters // 100
    cm = centimeters % 100
    return m, cm

# %%
medidas = to_meters(240)

# %%
medidas

# %%
# Usar funciones como argumento
def identidad(x):
    return x

def cuadrado(x):
    return x ** 2

def cubo(x):
    return x ** 3

def operacion(fn, x):
    return fn(x)

# %%
operacion(cuadrado, 2)

# %%
operacion(cubo, 3)

# %%
# Funciones que no retornan nada o procedimientos
a = 10

def reporte(nombre, rol, loc):
    x = 10
    print(a + x)
    print(f'Nombre: {nombre[0]} {nombre[1]}')
    print(f'Rol: {rol}')
    print(f'Ubicacion: {loc}')

# %%
reporte(('Esteban', 'Dido'), 'Coordinador', 'Edificio G')

# %% [markdown]
# ## Módulos
#
# Los módulos son colecciones de variables y funciones, o estructuras de datos.

# %%
import math

# %%
math.sin(math.pi / 2)

# %%
from math import sin, cos, pi

# %%
sin(pi / 2)

# %%
cos(0.0)

# %%
from random import choice, randrange, randint

# %%
choice(['uno', 'dos', 'tres', 'cinco'])

# %%
randrange(5, 10)

# %%
randint(10, 40)

# %%
from datetime import date

# %%
hoy = date(2025, 9, 14)
clases = date(2025, 10, 4)

(clases - hoy).days

# %%
hoy.weekday()

# %%
from my_module.funciones import impar

impar(5)

# %%
import my_module.funciones as mfunc

mfunc.impar(5)

# %% [markdown]
# ### Funcion "Main"

# %%
# def suma(x, y):
#     return x + y


# if __name__ == '__main__':
#     print(suma(3, 4))
